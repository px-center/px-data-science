# %%
from lib import *
import pandas as pd
import matplotlib.pyplot as plt

pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')


#dfs = load_data_bq()
dfs = load_data_db()
df_diaria = dfs["diaria"]
df_coleta_entrega = dfs["coleta_entrega"]
#55s
# Out:
# Conexão estabelecida com sucesso!

# %%
display(df_diaria.head())
display(df_coleta_entrega.head())
# Out:
#    activity_month avg_contracts_per_month
# 0             0.0      1.4893880438627520
# 1             1.0      1.9069195644538110
# 2             2.0      1.8287314925970388
# 3             3.0      1.7676959619952494
# 4             4.0      1.7341913822048125
#    activity_month avg_contracts_per_month
# 0             0.0      1.9237529077280951
# 1             1.0      3.2073613271124935
# 2             2.0      3.4143567874911158
# 3             3.0      3.4678260869565217
# 4             4.0      3.4302203567681007

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supondo que df_diaria já esteja definido
df = df_diaria.copy()

fig, ax = plt.subplots(figsize=(20, 10))

# Plota as barras com uma cor aprimorada
bars = ax.bar(df['activity_month'].astype(int), df['avg_contracts_per_month'], 
              color='skyblue', edgecolor='black')

# Configura os rótulos dos eixos e título com fontes maiores
ax.set_xlabel('Activity Month', fontsize=14)
ax.set_ylabel('Avg Contracts per Month', fontsize=14)
ax.set_title('Average Contracts per Activity Month\n Diária \n', fontsize=32)

# Define os ticks do eixo x com rotação
ax.set_xticks(df['activity_month'].astype(int))
ax.set_xticklabels(df['activity_month'].astype(int), rotation=45, fontsize=12)

# Adiciona linhas de grade no eixo y para facilitar a leitura dos valores
ax.yaxis.grid(True, linestyle='--', alpha=0.7)

# Anota o valor de cada barra
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # deslocamento para cima
                textcoords="offset points",
                ha='center', va='bottom', fontsize=12)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supondo que df_diaria já esteja definido
df = df_coleta_entrega.copy()

fig, ax = plt.subplots(figsize=(20, 10))

# Plota as barras com uma cor aprimorada
bars = ax.bar(df['activity_month'].astype(int), df['avg_contracts_per_month'], 
              color='skyblue', edgecolor='black')

# Configura os rótulos dos eixos e título com fontes maiores
ax.set_xlabel('Activity Month', fontsize=14)
ax.set_ylabel('Avg Contracts per Month', fontsize=14)
ax.set_title('Average Contracts per Activity Month\n Coleta/Entrega \n', fontsize=32)

# Define os ticks do eixo x com rotação
ax.set_xticks(df['activity_month'].astype(int))
ax.set_xticklabels(df['activity_month'].astype(int), rotation=45, fontsize=12)

# Adiciona linhas de grade no eixo y para facilitar a leitura dos valores
ax.yaxis.grid(True, linestyle='--', alpha=0.7)

# Anota o valor de cada barra
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # deslocamento para cima
                textcoords="offset points",
                ha='center', va='bottom', fontsize=12)

plt.tight_layout()
plt.show()
