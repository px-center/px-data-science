# %%
#!/usr/bin/env python3
"""
fraud_analysis.py

Script para análise de risco de fraude em reembolsos.
"""
import argparse
import logging
import sys
from datetime import timedelta
from collections import defaultdict

import pandas as pd

# --- Constantes de negócio ---
VALOR_CONTRATO_ALTO = 3000
VALOR_REEMBOLSO_ALTO = 3000
VALOR_REEMBOLSO_MEDIO = 500
VALOR_REEMBOLSO_MUITO_ALTO = 1000
TEMPO_APROVACAO_MAXIMO = timedelta(minutes=1)
HORARIO_NOTURNO = 21
VALOR_REEMBOLSO_NOTURNO = 300
PERCENTUAL_REEMBOLSOS_ALTO = 0.7
VARIACAO_LIMIAR = 0.3
REEMBOLSOS_POR_DIA_SUSPEITOS = 3
TRANSACOES_ALTAS_POR_DIA = 2
TAXA_REEMBOLSO_ALTA_CONTRATO = 0.2


def preparar_dados(caminho_csv: str) -> pd.DataFrame:
    """
    Carrega e prepara os dados de reembolso.
    - Converte tipos
    - Renomeia colunas
    - Remove linhas faltantes
    - Extrai data, hora e simula tempo de aprovação
    """
    df = pd.read_csv(caminho_csv)

    # Conversões
    df['updated_at'] = pd.to_datetime(df['updated_at'], errors='coerce')
    df['valor_reembolso'] = pd.to_numeric(df.get('Valor do reembolso', df.get('valor_reembolso')), errors='coerce')
    df['valor_contrato'] = pd.to_numeric(df.get('Valor do contrato', df.get('valor_contrato')), errors='coerce')
    df['dias_agenciados'] = pd.to_numeric(df.get('contract_days', df.get('dias_agenciados')), errors='coerce')

    # Renomear para consistência
    df.rename(columns={
        'company_name': 'transportadora',
        'driver_name': 'motorista'
    }, inplace=True)

    # Remover nulos críticos
    df.dropna(subset=['updated_at', 'valor_reembolso', 'valor_contrato', 'dias_agenciados'], inplace=True)

    # Extrair data e hora
    df['data_transacao'] = df['updated_at'].dt.date
    df['hora_transacao'] = df['updated_at'].dt.time

    # Simulação de tempo de aprovação (substituir por dado real se disponível)
    df['tempo_aprovacao_minutos'] = [i * 0.1 for i in range(len(df))]

    return df


def identificar_transacoes_suspeitas(df: pd.DataFrame) -> pd.DataFrame:
    """
    Marca cada transação como suspeita conforme regras de negócio.
    """
    def is_suspeita(row):
        # 1. 50% do contrato alto
        if row['valor_contrato'] >= VALOR_CONTRATO_ALTO and row['valor_reembolso'] >= 0.5 * row['valor_contrato']:
            return True
        # 2. Valor muito alto
        if row['valor_reembolso'] > VALOR_REEMBOLSO_ALTO:
            return True
        # 3. Aprovação rápida e valor médio
        if row['tempo_aprovacao_minutos'] < TEMPO_APROVACAO_MAXIMO.total_seconds() / 60 and row['valor_reembolso'] > VALOR_REEMBOLSO_MEDIO:
            return True
        # 4. Reembolso noturno
        if row['hora_transacao'].hour >= HORARIO_NOTURNO and row['valor_reembolso'] > VALOR_REEMBOLSO_NOTURNO:
            return True
        return False

    df['suspeita'] = df.apply(is_suspeita, axis=1)
    return df


def analisar_comportamento(df: pd.DataFrame) -> dict:
    """
    Para cada transportadora/motorista, calcula métricas acumuladas e dias suspeitos.
    """
    resultados = defaultdict(lambda: {
        'total_reembolsos': 0,
        'num_reembolsos': 0,
        'dias_agenciados': 1,
        'percentual_reembolsos': 0,
        'variacao_reembolsos': 0,
        'variacao_valor_reembolsos': 0,
        'dias_suspeitos': []
    })

    # Sumário de contratos
    soma_contratos = df.groupby(['transportadora', 'motorista'])['valor_contrato'].sum()
    media_embolsos_por_dia = df.groupby(['transportadora', 'motorista']).apply(
        lambda x: len(x) / x['dias_agenciados'].mean() if x['dias_agenciados'].mean() > 0 else 0
    )
    media_valor_por_dia = df.groupby(['transportadora', 'motorista'])['valor_reembolso'].sum() / \
        df.groupby(['transportadora', 'motorista'])['dias_agenciados'].mean().replace(0, 1)

    for (empresa, motorista), grupo in df.groupby(['transportadora', 'motorista']):
        total = grupo['valor_reembolso'].sum()
        count = len(grupo)
        dias = grupo['dias_agenciados'].mean() or 1
        contrato = soma_contratos.get((empresa, motorista), 1)

        pct = total / contrato if contrato > 0 else 0
        reemb_dia = count / dias
        valor_dia = total / dias

        var_count = abs((reemb_dia - media_embolsos_por_dia.loc[(empresa, motorista)]) / media_embolsos_por_dia.loc[(empresa, motorista)]) \
            if media_embolsos_por_dia.loc[(empresa, motorista)] else 0
        var_valor = abs((valor_dia - media_valor_por_dia.loc[(empresa, motorista)]) / media_valor_por_dia.loc[(empresa, motorista)]) \
            if media_valor_por_dia.loc[(empresa, motorista)] else 0

        # Dias com múltiplas transações
        dias_sus = []
        for d, g in grupo.groupby('data_transacao'):
            if len(g[g['valor_reembolso'] > VALOR_REEMBOLSO_MEDIO]) >= REEMBOLSOS_POR_DIA_SUSPEITOS \
               or len(g[g['valor_reembolso'] > VALOR_REEMBOLSO_MUITO_ALTO]) >= TRANSACOES_ALTAS_POR_DIA:
                dias_sus.append(d)

        resultados[(empresa, motorista)] = {
            'total_reembolsos': total,
            'num_reembolsos': count,
            'dias_agenciados': dias,
            'percentual_reembolsos': pct,
            'variacao_reembolsos': var_count,
            'variacao_valor_reembolsos': var_valor,
            'dias_suspeitos': dias_sus
        }

    return resultados


def apply_advanced_rules(resultados: dict) -> None:
    """
    Adiciona flag de "alto volume" segundo taxa em contrato.
    """
    for key, val in resultados.items():
        val['regra_volume_alto'] = val['percentual_reembolsos'] > TAXA_REEMBOLSO_ALTA_CONTRATO


def calcular_indicador_risco(resultados: dict) -> dict:
    """
    Computa um score de risco (número de alertas) por transportadora/motorista.
    """
    scores = {}
    for key, val in resultados.items():
        count = 0
        if val['percentual_reembolsos'] >= PERCENTUAL_REEMBOLSOS_ALTO: count += 1
        if val['variacao_reembolsos'] >= VARIACAO_LIMIAR: count += 1
        if val['variacao_valor_reembolsos'] >= VARIACAO_LIMIAR: count += 1
        if val['dias_suspeitos']: count += 1
        if val.get('regra_volume_alto'): count += 1
        scores[key] = count
    return scores


def gerar_relatorio(df: pd.DataFrame, resultados: dict, scores: dict) -> str:
    """
    Monta texto de relatório com detalhes e casos de alto risco.
    """
    rel = ["Análise de Risco de Fraude em Reembolsos:\n"]
    alto = [(k, s) for k, s in scores.items() if s >= 2]
    if not alto:
        rel.append("Nenhum caso de alto risco detectado.\n")
    else:
        rel.append("Transportadoras/Motoristas de Alto Risco:\n")
        for (empresa, motorista), s in sorted(alto, key=lambda x: -x[1]):
            rel.append(f"- {empresa} / {motorista}: alertas = {s}\n")
    return ''.join(rel)


# def main():
#     parser = argparse.ArgumentParser(description="Análise de risco de fraude em reembolsos.")
#     parser.add_argument('input_csv', help='Caminho para o arquivo de dados CSV')
#     parser.add_argument('--report', help='Arquivo de saída do relatório (texto)', default=None)
#     args = parser.parse_args()

#     logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

#     try:
#         df = preparar_dados(args.input_csv)
#         df = identificar_transacoes_suspeitas(df)
#         resultados = analisar_comportamento(df)
#         apply_advanced_rules(resultados)
#         scores = calcular_indicador_risco(resultados)
#         rel_text = gerar_relatorio(df, resultados, scores)

#         if args.report:
#             with open(args.report, 'w', encoding='utf-8') as f:
#                 f.write(rel_text)
#             logging.info(f"Relatório salvo em {args.report}")
#         else:
#             sys.stdout.write(rel_text)
#     except Exception as e:
#         logging.error(str(e))
#         sys.exit(1)


# if __name__ == '__main__':
#     main()

# %%
# 2. Carregue e prepare os dados
df = preparar_dados("./src/data/data.csv")

# 3. Identifique transações suspeitas
df = identificar_transacoes_suspeitas(df)

# 4. Analise o comportamento agregado
resultados = analisar_comportamento(df)

# 5. Aplique regras avançadas (flag de alto volume)
apply_advanced_rules(resultados)

# 6. Calcule o score de risco por transportadora/motorista
scores = calcular_indicador_risco(resultados)

# 7. Gere o relatório final
relatorio = gerar_relatorio(df, resultados, scores)

# 8. Exiba ou salve
print(relatorio)
# ou
with open("relatorio.txt", "w", encoding="utf-8") as f:
    f.write(relatorio)
# Out:
# /tmp/ipykernel_21333/3325807503.py:104: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   media_embolsos_por_dia = df.groupby(['transportadora', 'motorista']).apply(
# Análise de Risco de Fraude em Reembolsos:
# Transportadoras/Motoristas de Alto Risco:
# - ABC CARGAS LTDA / ANDRE LUIZ DOS SANTOS DE SOUZA: alertas = 3
# - ABC CARGAS LTDA / CARLOS ALMIR PAIXAO DA SILVA: alertas = 3
# - ABC CARGAS LTDA / CLAUDINEI BAPTISTA DOS SANTOS: alertas = 3
# - ABC CARGAS LTDA / DANTE BARBOSA DIAS CARNEIRO: alertas = 3
# - ABC CARGAS LTDA / DAVID CICERO DA SILVA ALMEIDA: alertas = 3
# - ABC CARGAS LTDA / HAILTON PAIVA BARBOSA: alertas = 3
# - ABC CARGAS LTDA / ISAIAS DE LIMA BATISTA: alertas = 3
# - ABC CARGAS LTDA / JOSE MARTINS BARBOSA DE OLIVEIRA: alertas = 3
# - ABC CARGAS LTDA / LUIZ CARLOS DE REZENDE: alertas = 3
# - ABC CARGAS LTDA / MANOEL ROSA DOS SANTOS: alertas = 3
# - ABC CARGAS LTDA / NORTON LUIS DE ALMEIDA: alertas = 3
# - ABC CARGAS LTDA / ROSIVALDO MANOEL DA SILVA: alertas = 3
# - ABC CARGAS LTDA / anonymous: alertas = 3
# - ATHIVALOG - CUIABA / UGLEIDSON FERREIRA DE BARROS: alertas = 3
# - AXON TRANSPORTES S/A / JOHN PASCH: alertas = 3
# - Atmosfera - Jundiaí Industrial / VALDENILSON MORAES: alertas = 3
# - Dalla Valle Transportes / VLADIMIR ROBERTO BRAGE: alertas = 3
# - GPSA - CD ALAGOINHAS / ELISIO MOREIRA NEVES FILHO: alertas = 3
# - GPSA - CD ALAGOINHAS / JOSE RAIMUNDO SOARES DE LIMA: alertas = 3
# - GPSA - CD ALAGOINHAS / LUIS SOARES DE LIMA: alertas = 3
# - Grupo Laredo / MARCOS PAULO PIMENTEL DA SILVA: alertas = 3
# - IBL LOGISTICA / ORLANDO ALVES BARBOSA: alertas = 3
# - MECBRUN INDUSTRIAL / MARCELO GUIMARÃES MORAIS: alertas = 3
# - Pedreira Bangu LTDA / MAICON ALVES DE OLIVEIRA: alertas = 3
# - Pedreira Bangu LTDA / RADU VASILE PUIA: alertas = 3
# - SEMALO INDUSTRIA E COMERCIO DE ALIMENTOS LTDA / VERALDINO DIAS SILVA FILHO: alertas = 3
# - SEMALO INDUSTRIA E COMERCIO DE ALIMENTOS LTDA / ÉVERTON PAULO DA SILVA: alertas = 3
# - Transportes Maçaneiro LTDA / JOãO CARLOS BENEVITE: alertas = 3
# - 4TAKES Indústria, Comércio, Serviços e Participações Ltda / FELIPE RAFAEL DOS SANTOS: alertas = 2
# - 4TAKES Indústria, Comércio, Serviços e Participações Ltda / RAFAEL DA SILVA DUARTE: alertas = 2
# - 4TAKES Indústria, Comércio, Serviços e Participações Ltda / WASHINGTON PEREIRA FRANCA: alertas = 2
# - ABC CARGAS LTDA / ADEMIR DE SOUSA COSTA: alertas = 2
# - ABC CARGAS LTDA / ADRIANO DOS SANTOS CASSIANO: alertas = 2
# - ABC CARGAS LTDA / AIRTON AUGUSTO DA SILVA: alertas = 2
# - ABC CARGAS LTDA / ALESSANDRO MARCELO SINGER: alertas = 2
# - ABC CARGAS LTDA / ANDERSON ANTONIO MANDUCA: alertas = 2
# - ABC CARGAS LTDA / ANDERSON GOMES VIEIRA: alertas = 2
# - ABC CARGAS LTDA / ANDRE RICARDO LAZARO: alertas = 2
# - ABC CARGAS LTDA / ANGEL JOSE RODRIGUEZ ALVAREZ: alertas = 2
# - ABC CARGAS LTDA / ANTONIO CAMILO ALMEIDA FREITAS JUNIOR: alertas = 2
# - ABC CARGAS LTDA / ANTONIO MARCOS JESUS DA SILVA: alertas = 2
# - ABC CARGAS LTDA / APARECIDO REIS GODOY: alertas = 2
# - ABC CARGAS LTDA / BRUNO ANTONIO CAMARGO: alertas = 2
# - ABC CARGAS LTDA / BRUNO DE SOUSA BEZERRA: alertas = 2
# - ABC CARGAS LTDA / CARLOS EDUARDO CECEL DA SILVA MARCAL: alertas = 2
# - ABC CARGAS LTDA / CLEANDERSON AALE VIEIRA DOS SANTOS: alertas = 2
# - ABC CARGAS LTDA / CRISTIAM WANDERLEI BORBA: alertas = 2
# - ABC CARGAS LTDA / EDUARDO APARECIDO SALES: alertas = 2
# - ABC CARGAS LTDA / ELISMAEL DO NASCIMENTO: alertas = 2
# - ABC CARGAS LTDA / EMERSON GERMANO MEIRA: alertas = 2
# - ABC CARGAS LTDA / FABIO SANTIAGO DA COSTA: alertas = 2
# - ABC CARGAS LTDA / FELLIPE SANTOS DA COSTA: alertas = 2
# - ABC CARGAS LTDA / FRANCISCO ALEXANDRE SOUZA: alertas = 2
# - ABC CARGAS LTDA / FRANCISCO UILHAMIS FERNANDES CAVALCANTE: alertas = 2
# - ABC CARGAS LTDA / FRANKLIN VALERIO DE MELLO: alertas = 2
# - ABC CARGAS LTDA / GERMANO RAFAEL VILLARINHO RUTZ: alertas = 2
# - ABC CARGAS LTDA / GILBERTO SANTOS DE ANDRADE FILHO: alertas = 2
# - ABC CARGAS LTDA / HAYSEN SINIEGHI JORDAO: alertas = 2
# - ABC CARGAS LTDA / HENRIQUE DE SOUZA: alertas = 2
# - ABC CARGAS LTDA / JARBAS FERREIRA DOS ANJOS: alertas = 2
# - ABC CARGAS LTDA / JOAO BATISTA DE OLIVEIRA: alertas = 2
# - ABC CARGAS LTDA / JOAO BRAZ DA SILVA IRMAO: alertas = 2
# - ABC CARGAS LTDA / JOSE ALVES DE LIMA: alertas = 2
# - ABC CARGAS LTDA / JOSE ANGEL LOPEZ: alertas = 2
# - ABC CARGAS LTDA / JOSE CARLOS DIAS DE OLIVEIRA: alertas = 2
# - ABC CARGAS LTDA / JOSE CELIO GOMES DA SILVA: alertas = 2
# - ABC CARGAS LTDA / JOSE MARCELO DE OLIVEIRA: alertas = 2
# - ABC CARGAS LTDA / JUAN CARLOS LUGO REYES: alertas = 2
# - ABC CARGAS LTDA / KEVIN FERNANDES DE ARAUJO: alertas = 2
# - ABC CARGAS LTDA / LEANDRO SANTOS DE ALMEIDA: alertas = 2
# - ABC CARGAS LTDA / LEONIDAS CLAUDINO DO NASCIMENTO: alertas = 2
# - ABC CARGAS LTDA / LEOTINO PEREIRA DE OLIVEIRA: alertas = 2
# - ABC CARGAS LTDA / LUCIANO ALVES: alertas = 2
# - ABC CARGAS LTDA / LUIZ FERNANDO BARBIERI: alertas = 2
# - ABC CARGAS LTDA / MARCELO JUNIO DE OLIVEIRA GUERREIRO: alertas = 2
# - ABC CARGAS LTDA / MARCELO RODRIGUES SANTOS: alertas = 2
# - ABC CARGAS LTDA / MARCOS ARAUJO DO NASCIMENTO: alertas = 2
# - ABC CARGAS LTDA / OSWALDO OLIVEIRA JUNIOR: alertas = 2
# - ABC CARGAS LTDA / PAULO CEZAR COCATO: alertas = 2
# - ABC CARGAS LTDA / PAULO DOMINGOS DA MOTA: alertas = 2
# - ABC CARGAS LTDA / PAULO HENRIQUE DE MEDEIROS ANDRADE: alertas = 2
# - ABC CARGAS LTDA / PEDRO PEREZ DOS SANTOS: alertas = 2
# - ABC CARGAS LTDA / RAFAEL AUGUSTO DA COSTA: alertas = 2
# - ABC CARGAS LTDA / RAMON RODRIGUES LERMES: alertas = 2
# - ABC CARGAS LTDA / REGINALDO MARCELINO DE OLIVEIRA: alertas = 2
# - ABC CARGAS LTDA / ROBERTO CARLOS DE GOIS: alertas = 2
# - ABC CARGAS LTDA / ROBERTO OLIVEIRA DOS SANTOS: alertas = 2
# - ABC CARGAS LTDA / ROBERTO SANTOS DA SILVA: alertas = 2
# - ABC CARGAS LTDA / RODRIGO FERREIRA DOS SANTOS: alertas = 2
# - ABC CARGAS LTDA / RODRIGO ROSA DE PAULA: alertas = 2
# - ABC CARGAS LTDA / ROGERIO LUIS MUNIZ ARESI: alertas = 2
# - ABC CARGAS LTDA / RONIEL PEREIRA DA SILVA: alertas = 2
# - ABC CARGAS LTDA / ROSBERG CESAR FERREIRA DA SILVA: alertas = 2
# - ABC CARGAS LTDA / RUBENILSON ALLISON DA SILVA: alertas = 2
# - ABC CARGAS LTDA / SAMUEL GUSSO SANTOS: alertas = 2
# - ABC CARGAS LTDA / SEBASTIAO CEZARIO DIAS: alertas = 2
# - ABC CARGAS LTDA / SILVANO FRANCISCO RODRIGUES: alertas = 2
# - ABC CARGAS LTDA / TADEU APARECIDO DE ASSIS: alertas = 2
# - ABC CARGAS LTDA / THIAGO LOPES MUNHOZ: alertas = 2
# - ABC CARGAS LTDA / UELTON DE OLIVEIRA: alertas = 2
# - ABC CARGAS LTDA / WENDEL CRISTIANO TAVARES: alertas = 2
# - ABC CARGAS LTDA / WESLEY RODRIGUES DA SILVA: alertas = 2
# - ABC CARGAS LTDA / WILLIAN COBAS OLIVA: alertas = 2
# - ABC CARGAS LTDA / WILLIAN MOURA DA SILVA: alertas = 2
# - ABC CARGAS LTDA / WILLIS EDSON VICENTE: alertas = 2
# - ADDIANTE SA / RODRIGO NORATO GONÇALVES: alertas = 2
# - ALIANCA TRANSPORTES RODOVIARIOS LTDA / NATHANAEL SOUZA DE MENEZES: alertas = 2
# - ANACIREMA TRANSPORTES LTDA / EMANUEL ALVES NASCIMENTO: alertas = 2
# - ANDIMA TRANSPORTES PESADOS LTDA / GILMAR PADILHA: alertas = 2
# - ATHIVALOG - CUIABA / EDILSON RODRIGUES DE ARRUDA: alertas = 2
# - ATHIVALOG - CUIABA / LUIZ FERNANDO PAES DE DEUS OLIVEIRA: alertas = 2
# - ATHIVALOG - CUIABA / OSVALDO DAMASCENO NETO: alertas = 2
# - ATHIVALOG - CUIABA / WILLIAN MIRANDA DA SILVA: alertas = 2
# - ATHIVALOG - GOIANIA / WEVERSON DOMINGUES SOBRINHO: alertas = 2
# - AXON TRANSPORTES S/A / MARCEL ROGERIO BERSANI: alertas = 2
# - AXON TRANSPORTES S/A / ROGERIO DUARTE: alertas = 2
# - AXON TRANSPORTES S/A / VALDECIR PEREIRA DOS SANTOS: alertas = 2
# - Atmosfera - Jundiaí Industrial / AGLIMAR GOMES DA SILVEIRA: alertas = 2
# - Atmosfera - Jundiaí Industrial / JONES ARAGÃO PEREIRA: alertas = 2
# - Atmosfera - Jundiaí Industrial / MATHEUS GUILHERME GOMES MORAES: alertas = 2
# - Atmosfera - Jundiaí Industrial / PEDRO BERNARDO: alertas = 2
# - Atmosfera - Jundiaí Industrial / WELLINGTON DOS SANTOS: alertas = 2
# - CARGOLIFT LOGíSTICA SA - PEDRO OSNI / EDSON EZIQUIEL DOS SANTOS: alertas = 2
# - CARVALIMA TRANSPORTES / ANTONIO MARCOS DAMASCENO SANTOS: alertas = 2
# - CARVALIMA TRANSPORTES / EDINEI SILVA BARRETO: alertas = 2
# - CARVALIMA TRANSPORTES / EDSON ROSA DA MOTTA: alertas = 2
# - CARVALIMA TRANSPORTES / JOSE LAERCIO DOS SANTOS: alertas = 2
# - CARVALIMA TRANSPORTES / JOSÉ TIAGO DE CARVALHO CHAGAS: alertas = 2
# - CARVALIMA TRANSPORTES / MARCIO BRITES DA SILVA: alertas = 2
# - CARVALIMA TRANSPORTES / MARCIO GUIMARAES SILVA PAZ: alertas = 2
# - CARVALIMA TRANSPORTES / MARLON LUCIO GONÇALVES DE FREITAS: alertas = 2
# - CARVALIMA TRANSPORTES / PAULO ROGERIO JULIO: alertas = 2
# - CARVALIMA TRANSPORTES / RONALDO MONTEIRO DOS SANTOS: alertas = 2
# - CARVALIMA TRANSPORTES / VALDEMIR ROSA SALVADOR: alertas = 2
# - CARVALIMA TRANSPORTES / VITOR HUGO FERNANDES DA SILVA: alertas = 2
# - COMERCIO E TRANSPORTES MIORANZA LTDA / ROBERTO JEFERSON ALVES DE SOUZA: alertas = 2
# - CONCRELAGOS CONCRETO SA / JEFFERSON FERNANDO MIRANDA SAMPAIO: alertas = 2
# - Cargolift Logística SA - Pedro / MARCOS ANTONIO RODRIGUES: alertas = 2
# - Dinâmica construções e serviços ltda / BRUNO FARIAS ALVES MARINHO: alertas = 2
# - Dinâmica construções e serviços ltda / LUIZ ANDRE DE JESUS MELO: alertas = 2
# - EAGLE - VOLTA REDONDA / ATAINON ALVES DO CARMO: alertas = 2
# - EMPRESA BRASILEIRA DE ENGENHARIA E COMERCIO SA - EBEC / JAILTON JESUS DOS SANTOS: alertas = 2
# - ENGENHARIA E COMERCIO BANDEIRANTES LTDA / JEOVANE JOSE DE OLIVEIRA: alertas = 2
# - ENGENHARIA E COMERCIO BANDEIRANTES LTDA / SERGIO SILVA BARROSO: alertas = 2
# - EXPRESSO NEPOMUCENO - SANTA LUZIA / ATILA ALVES GUICHARDI: alertas = 2
# - FEDEX - CPQ - CAMPINAS / JOSE HUGO MATIAS BARBOSA: alertas = 2
# - FEDEX - UVT - UNIAO DA VITORIA / ARGENIS MOISES SULBARAN REQUENA: alertas = 2
# - FSJ - MATHEUS VIVOT / ADENILDO ELEOTERIO DOS SANTOS: alertas = 2
# - GPSA - CD ALAGOINHAS / ISMAEL DOS SANTOS PEREIRA BARBOSA: alertas = 2
# - GPSA - CD BARREIRAS / HERBERT DOS SANTOS MOREIRA DE ASSIS: alertas = 2
# - GPSA - CD CARIACICA / CARLOS ELESSANDRO DE PAIVA: alertas = 2
# - GPSA - CD CARIACICA / ELUILSON FERREIRA DE OLIVEIRA: alertas = 2
# - GPSA - CD CARIACICA / MANOEL HENRIQUE GONCALVES DOS SANTOS: alertas = 2
# - GPSA - CD SÃO MATEUS / JOSIMAR DA ROCHA LIMA: alertas = 2
# - GRUPO VB ALIMENTOS / ADEVALDO LIRA MORENO: alertas = 2
# - GT FOODS - APUCARANA / ADEMILSON MIGUEL SILVA: alertas = 2
# - GT FOODS - APUCARANA / ANDERSON RIBEIRO DINIZ: alertas = 2
# - GT FOODS - APUCARANA / ANTONIO CARLOS NASCIMENTO GOMES: alertas = 2
# - GT FOODS - APUCARANA / CLAUDINEI VICENTE GUEDES: alertas = 2
# - GT FOODS - APUCARANA / CLAUDIO BATISTA LAMIM: alertas = 2
# - GT FOODS - APUCARANA / CLEBER GOMES DE OLIVEIRA: alertas = 2
# - GT FOODS - APUCARANA / EDER DAS DORES PAULA: alertas = 2
# - GT FOODS - APUCARANA / EDSON SEVERINO DA SILVA: alertas = 2
# - GT FOODS - APUCARANA / ELSON PEREIRA DE ANDRADE: alertas = 2
# - GT FOODS - APUCARANA / EVERTON FORMIGONI FRANCESQUI: alertas = 2
# - GT FOODS - APUCARANA / JHONATHAN SANTOS MATHEUS: alertas = 2
# - GT FOODS - APUCARANA / JOAO BATISTA SANTOS DA SILVA: alertas = 2
# - GT FOODS - APUCARANA / LEANDRO LINDOMAR DE DEUS: alertas = 2
# - GT FOODS - APUCARANA / MARCELO DE BARROS PRESSINOTTE: alertas = 2
# - GT FOODS - APUCARANA / MARCELO MARQUES: alertas = 2
# - GT FOODS - APUCARANA / MARCELO PADILHA SPECIAN: alertas = 2
# - GT FOODS - APUCARANA / MOISES DE OLIVEIRA DOMINGOS: alertas = 2
# - GT FOODS - APUCARANA / SEVERIANO BRAZ DA CRUZ: alertas = 2
# - GT FOODS - APUCARANA / VANESSA MOURA DA SILVA: alertas = 2
# - GT FOODS - APUCARANA / WELLINGTON MARTINS DA SILVA: alertas = 2
# - GT FOODS - BARUERI / ADEMILSON MIGUEL SILVA: alertas = 2
# - GT FOODS - BARUERI / ADEMIR DA SILVA: alertas = 2
# - GT FOODS - BARUERI / ADILSON DOMINGOS MACHADO: alertas = 2
# - GT FOODS - BARUERI / AMAURI DO CARMO SAMPAIO: alertas = 2
# - GT FOODS - BARUERI / CARLOS EDUARDO CECEL DA SILVA MARCAL: alertas = 2
# - GT FOODS - BARUERI / CELSO FERREIRA DE SOUZA: alertas = 2
# - GT FOODS - BARUERI / CLAUDIO SANTOS DE SOUSA: alertas = 2
# - GT FOODS - BARUERI / EDUARDO BEZERRA DA SILVA: alertas = 2
# - GT FOODS - BARUERI / EVERTON FORMIGONI FRANCESQUI: alertas = 2
# - GT FOODS - BARUERI / FABIO SANTIAGO DA COSTA: alertas = 2
# - GT FOODS - BARUERI / FLAVIO JOSE JOVINO DOS ANJOS: alertas = 2
# - GT FOODS - BARUERI / JEOVÁ DE LIMA SANTOS: alertas = 2
# - GT FOODS - BARUERI / JONAS DA SILVA: alertas = 2
# - GT FOODS - BARUERI / JOSE CARLOS DE SOUZA: alertas = 2
# - GT FOODS - BARUERI / JOSE MARCIO CORDEIRO SOARES: alertas = 2
# - GT FOODS - BARUERI / LEANDRO DO NASCIMENTO SGUILACE: alertas = 2
# - GT FOODS - BARUERI / MARCOS VINICIUS DINIZ PEDROSA: alertas = 2
# - GT FOODS - BARUERI / MAURICIO FRANCISCO DE OLIVEIRA: alertas = 2
# - GT FOODS - BARUERI / PAULO HENRIQUE ALVES BARBOZA: alertas = 2
# - GT FOODS - BARUERI / ROBERTO ALESSANDRO ALVES DE SOUZA: alertas = 2
# - GT FOODS - BARUERI / RONALDO PIRES DE AZEVEDO: alertas = 2
# - GT FOODS - BARUERI / SEBASTIAO CEZARIO DIAS: alertas = 2
# - GT FOODS - BARUERI / WELLINGTON MARTINS DA SILVA: alertas = 2
# - GT FOODS - BARUERI / WENDELL OLIVEIRA SANTOS LOPES: alertas = 2
# - GT FOODS - PONTA GROSSA / ADEMILSON MIGUEL SILVA: alertas = 2
# - GT FOODS - PONTA GROSSA / ADRIANO BORGES: alertas = 2
# - GT FOODS - PONTA GROSSA / FABIANO DOS SANTOS VANDOSKI: alertas = 2
# - GT FOODS - PONTA GROSSA / RODRIGO EVALDO OLIVEIRA: alertas = 2
# - GT FOODS - PONTA GROSSA / THIAGO LOPES MUNHOZ: alertas = 2
# - GT FOODS - QUEIMADOS / ADENILDO ELEOTERIO DOS SANTOS: alertas = 2
# - GT FOODS - QUEIMADOS / ALTAIR CEZARIO BRANDÃO: alertas = 2
# - GT FOODS - iTAJAI / ADEMILSON MIGUEL SILVA: alertas = 2
# - GT FOODS - iTAJAI / ALDENIR SANTOS BARAUNA: alertas = 2
# - GT FOODS - iTAJAI / DIEGO PERGER DA COSTA: alertas = 2
# - GT FOODS - iTAJAI / EVERTON FORMIGONI FRANCESQUI: alertas = 2
# - GT FOODS - iTAJAI / JOSE CARLOS DE SOUZA: alertas = 2
# - GT FOODS - iTAJAI / LUAN PEREIRA FREITAS: alertas = 2
# - GT FOODS - iTAJAI / LUIS ALBERTO RIBEIRO DE MATOS: alertas = 2
# - GT FOODS - iTAJAI / MURILO HENRIQUE: alertas = 2
# - Grupo Laredo / GUSTAVO FREITAS DE OLIVEIRA: alertas = 2
# - HB TRANSPORTES E LOGISTICA LTDA / HAMZA ISSA MOHAMMAD SMREEN: alertas = 2
# - HELTE / MAURíCIO DE ALMEIDA SANTOS: alertas = 2
# - IC TRANSPORTES AIRLIQUIDE / NORMILDO BRANDAO SANTOS: alertas = 2
# - IC TRANSPORTES TANQUE / VALDECIR BORGES DA SILVA: alertas = 2
# - IC Transportes (Laís) / MARCIO CAZUZA DA SILVA: alertas = 2
# - ICONEX LOGISTICA LTDA / PAULO DE SOUZA JARDIM: alertas = 2
# - IMEDIATO - CURITIBA / GILSON PEREIRA: alertas = 2
# - INFRABRASIL OBRAS PESADAS E MINERACAO LTDA / ELMER DO AMARAL CESAR: alertas = 2
# - INFRABRASIL OBRAS PESADAS E MINERACAO LTDA / JOAO PAULO NASCIMENTO DA SILVA: alertas = 2
# - INFRABRASIL OBRAS PESADAS E MINERACAO LTDA / LIONALDO NONATO DE MOURA: alertas = 2
# - INFRABRASIL OBRAS PESADAS E MINERACAO LTDA / VANESSA MOURA DA SILVA: alertas = 2
# - INFRABRASIL OBRAS PESADAS E MINERACAO LTDA / WELTON CASTELHANO ROSA DOS SANTOS: alertas = 2
# - JM TRANSPORTES / ROBSON LEONARDO DA SILVA: alertas = 2
# - JSL - CONTAGEM / ARIOVALDO ALBERTO CORREA DA SILVEIRA: alertas = 2
# - JSL - CONTAGEM / FABIO PAULO DA SILVA: alertas = 2
# - JSL S.A. - OSASCO (UNILEVER) / ALTINO MACHADO: alertas = 2
# - JSL S.A.- MATRIZ (HEINEKEN) / ALEXSSANDRO BUDOIA: alertas = 2
# - Kona Transportes - Itapecerica / WELLINGTON ALVES AMANCIO: alertas = 2
# - Kona Transportes - Jundiaí / EDUARDO CARDOSO LIMA: alertas = 2
# - LEMAR LOGISTICA E TRANSPORTES LTDA / EDER DE ALMEIDA: alertas = 2
# - LOG20 - Londrina / MARCELO SILVA ARAUJO: alertas = 2
# - LOGISTICA INTEGRADA MERCURIO LTDA / JEFERSON GONCALVES RIBEIRO: alertas = 2
# - LOGISTICA INTEGRADA MERCURIO LTDA / THIAGO DA SILVA MENDES: alertas = 2
# - MAESTRO LOCADORA DE VEICULOS S.A. / CARLOS DE SOUZA: alertas = 2
# - MAESTRO LOCADORA DE VEICULOS S.A. / DOUGLAS LEANDRO FRANZONI: alertas = 2
# - MAESTRO LOCADORA DE VEICULOS S.A. / LUIS THIAGO BARBOSA RODRIGUES: alertas = 2
# - MAESTRO LOCADORA DE VEICULOS S.A. / NATHANAEL SOUZA DE MENEZES: alertas = 2
# - MECBRUN INDUSTRIAL / 0: alertas = 2
# - MECBRUN INDUSTRIAL / CARLOS ALEXANDRE DE OLIVEIRA: alertas = 2
# - MECBRUN INDUSTRIAL / CARLOS ALEXANDRE MARIANO DOURADO: alertas = 2
# - MECBRUN INDUSTRIAL / CLAUDIO BATISTA LAMIM: alertas = 2
# - MECBRUN INDUSTRIAL / CLEONIR BIAVA SOARES: alertas = 2
# - MECBRUN INDUSTRIAL / CRISVALNEI COELHO DA COSTA: alertas = 2
# - MECBRUN INDUSTRIAL / EDUARDO BEZERRA DA SILVA: alertas = 2
# - MECBRUN INDUSTRIAL / EULLER MOREIRA XAVIER: alertas = 2
# - MECBRUN INDUSTRIAL / JOSE DOS SANTOS: alertas = 2
# - MECBRUN INDUSTRIAL / JOSE PAULO OLIVEIRA DE MOURA: alertas = 2
# - MECBRUN INDUSTRIAL / KLEBER LUCAS TRINDADE SANTOS: alertas = 2
# - MECBRUN INDUSTRIAL / LUCAS SILVA LIMA: alertas = 2
# - MECBRUN INDUSTRIAL / MARCOS DOS SANTOS DE CARVALHO: alertas = 2
# - MECBRUN INDUSTRIAL / MARIO LUCIO DE SALES: alertas = 2
# - MECBRUN INDUSTRIAL / MOISES DE OLIVEIRA DOMINGOS: alertas = 2
# - MECBRUN INDUSTRIAL / PAULO ALCANTARA DA SILVA: alertas = 2
# - MECBRUN INDUSTRIAL / RICARDO TOLENTINO: alertas = 2
# - N&LOG TRANSPORTES E LOGISTICA LTDA / VICTOR SATURNINO DE MELO: alertas = 2
# - NP TRANSPORTES / AMAURI DO CARMO SAMPAIO: alertas = 2
# - OPR Logistica Pontual / LINDEMBERG LOPES MARTINS: alertas = 2
# - OPR Logistica Pontual / LUIZ CARLOS DE SOUZA JUNIOR: alertas = 2
# - PALLAORO LOGISTICA E ARMAZENAGEM LTDA / ANDRE LUIZ CAMPOS APOLLO: alertas = 2
# - PETROPOLIS FILIAL / JOELTON FIUZA: alertas = 2
# - PETROPOLIS FILIAL / JOSE FERNANDO SOARES VIEIRA: alertas = 2
# - PETROPOLIS FILIAL / MACIEL LIMA BARBOSA: alertas = 2
# - PETROPOLIS FILIAL / MANUEL DE LIMA PINTO: alertas = 2
# - PETROPOLIS FILIAL / PAULO CESAR ZUCCARI: alertas = 2
# - PETROPOLIS FILIAL / REGINALDO RUBENS DE OLIVEIRA: alertas = 2
# - Pedreira Bangu LTDA / ALEX BARROS PASSOS: alertas = 2
# - Perfilog Logistica e Transportes Ltda / JOAQUIM DE JESUS GONCALVES SANTOS: alertas = 2
# - RAMTHUN / WELLINGTON DE SOUZA SILVA: alertas = 2
# - REVESP TRANSPORTES E SERVIÇOS LTDA / ALEXANDRE GOMES NETO: alertas = 2
# - REVESP TRANSPORTES E SERVIÇOS LTDA / CICERO MANOEL DA SILVA: alertas = 2
# - REVESP TRANSPORTES E SERVIÇOS LTDA / DIEGO HENRIQUE ONESKO: alertas = 2
# - REVESP TRANSPORTES E SERVIÇOS LTDA / DOUGLAS RODRIGUES DA SILVA: alertas = 2
# - REVESP TRANSPORTES E SERVIÇOS LTDA / EDINALDO SALES DOS SANTOS: alertas = 2
# - REVESP TRANSPORTES E SERVIÇOS LTDA / EDMILSON SILVA MOREIRA: alertas = 2
# - REVESP TRANSPORTES E SERVIÇOS LTDA / JOAO VITOR CUPERTINO DA SILVA: alertas = 2
# - REVESP TRANSPORTES E SERVIÇOS LTDA / LEONARDO CELESTINO DE SOUZA FERNANDES: alertas = 2
# - REVESP TRANSPORTES E SERVIÇOS LTDA / WALTER MAURICIO OLIVEIRA MARTINS: alertas = 2
# - REVLOC GESTAO E TERCEIRIZACAO DE FROTAS / FRANCISCO JUCIEL BARBOSA: alertas = 2
# - RODALOG - BLUMENAU / VANDERLEI CARARO: alertas = 2
# - RODALOG - CAXIAS DO SUL / VANDERLEI CARARO: alertas = 2
# - RODALOG - JOINVILLE / ALYFER CRISTYAN ALVES LOURENÇO: alertas = 2
# - RODALOG - JOINVILLE / GUILHERME MATHEUS PADILHA BARBOSA: alertas = 2
# - RODALOG - JOINVILLE / RENAN DE SOUZA MARIA: alertas = 2
# - RODOVIARIO CRISMARA LTDA / MARCOS AURELIO AMORIM: alertas = 2
# - SAVE INTELIGENCIA CORPORATIVA / CRISTIANO AUGUSTO PAULO: alertas = 2
# - SAVE INTELIGENCIA CORPORATIVA / RANULPHO DA SILVA QUEIROZ NETO: alertas = 2
# - SAVE INTELIGENCIA CORPORATIVA / REGINALDO DOS SANTOS DE PONTES: alertas = 2
# - SEMALO - MS / ADRIANO SOUZA SILVA: alertas = 2
# - SEMALO - MS / EDER SOARES VIEIRA: alertas = 2
# - SEMALO - MS / JESIEL ARRUDA DA SILVA: alertas = 2
# - SEMALO - MS / JOSE CARLOS CORREA: alertas = 2
# - SEMALO - MS / JUNIOR FERREIRA PEREIRA: alertas = 2
# - SEMALO - MS / LUIS CARLOS OROSCO: alertas = 2
# - SEMALO - MS / RODRIGO SANTOS DE OLIVEIRA: alertas = 2
# - SEMALO - MS / RONY VIEIRA TIAGO: alertas = 2
# - SEMALO - MS / WELLINGTON APARECIDO BATISTA DE SOUZA: alertas = 2
# - SEMALO - RS / CRISTIANO LIMA DA SILVA: alertas = 2
# - SEMALO - RS / ERIC ESPíRITO SANTO SANGUINE: alertas = 2
# - SEMALO - RS / SILVIO ANTONIO GONZAGA: alertas = 2
# - SEMALO INDUSTRIA E COMERCIO DE ALIMENTOS LTDA / EVERSON LUIZ FERREIRA: alertas = 2
# - SEQUOIA LOGISTICA E TRANSPORTES S.A / ANTONIO CARLOS NASCIMENTO GOMES: alertas = 2
# - SEQUOIA LOGISTICA E TRANSPORTES S.A / MARCOS ANDRADE DE LIMA: alertas = 2
# - SEQUOIA LOGISTICA E TRANSPORTES S.A / MOISES DE OLIVEIRA DOMINGOS: alertas = 2
# - SEQUOIA LOGISTICA E TRANSPORTES S.A / TIAGO LIMA DA SILVA: alertas = 2
# - TECMAR TRANSPORTES LTDA - MATRIZ / MARCOS DE SALDANHA DA GAMA: alertas = 2
# - TECMAR TRANSPORTES LTDA - MATRIZ / VALDECI ROSA DA SILVA: alertas = 2
# - TG LOGISTICA E TRANSPORTES LTDA / JOSEMILTON FERREIRA DA SILVA: alertas = 2
# - TRANSMASSA LOGISTICA LTDA / FERNANDO APARECIDO SIQUEIRA DA SILVA: alertas = 2
# - TRANSPANORAMA - ICARO / DEMILSON AMARAL: alertas = 2
# - TRANSPANORAMA - ICARO / TIAGO APARECIDO DA SILVA: alertas = 2
# - TRANSPANORAMA - MICHEL RIBEIRO / ALEXANDRE DE SOUSA MATIAS: alertas = 2
# - TRANSPANORAMA - MICHEL RIBEIRO / SERGIO DA SILVA: alertas = 2
# - TRANSPANORAMA - Operação Correio - Ivan / CAROLINA PEREIRA RAMOS: alertas = 2
# - TRANSPANORAMA - TIAGO / CID MARIO OTTO FILHO: alertas = 2
# - TRANSPANORAMA - TIAGO / ROBERTO QUEIROZ DA SILVA: alertas = 2
# - TRANSPORTADORA AK LTDA / DIEGO ADOLFO PRUCH DA SILVA: alertas = 2
# - TRANSPORTADORA AK LTDA / DIONI RAFAEL SOARES DE OLIVEIRA: alertas = 2
# - TRANSPORTADORA AK LTDA / GILBERTO SANTOS DE ANDRADE FILHO: alertas = 2
# - TRANSPORTADORA AK LTDA / JURANDIR ALVES BARBOSA: alertas = 2
# - TRANSPORTADORA AK LTDA / MARCOS ANTONIO DA SILVA: alertas = 2
# - TRANSPORTADORA AK LTDA / OSWALDO OLIVEIRA JUNIOR: alertas = 2
# - TRANSPORTADORA AK LTDA / RAFAEL DE OLIVEIRA TECLO: alertas = 2
# - TRANSPORTADORA AK LTDA / RICARDO DE SOUSA RODRIGUES: alertas = 2
# - TRANSPORTADORA AK LTDA / SEBASTIAO CEZARIO DIAS: alertas = 2
# - TRANSPORTADORA AK LTDA / WESLEY ANDERSON MARTINS SANTOS: alertas = 2
# - TRANSPORTADORA SCAPINI / IGOR FERREIRA COUTO: alertas = 2
# - TRANSPORTES GRITSCH LTDA / JUNIOR FERREIRA PEREIRA: alertas = 2
# - TRANSPORTES OURO NEGRO LTDA / LUIZ CARLOS SIMOES DA SILVA: alertas = 2
# - TRANSPORTES TOZZO LTDA / DEIVYS ANTONIO MORALES VENTO: alertas = 2
# - TRIANA LOG LTDA / JOCIEL OFIR RODRIGUES: alertas = 2
# - TRIANA LOG LTDA / ROBERTO RIBEIRO DE FREITAS: alertas = 2
# - TRIANA LOG LTDA / THIAGO LOPES MUNHOZ: alertas = 2
# - Transmarine / ANDREIA CRISTINA LIEBETANZ ALVES: alertas = 2
# - Transmarine / CLEBER SAMUEL CONSTANTINO: alertas = 2
# - Transmarine / ELISMAEL DO NASCIMENTO: alertas = 2
# - Transmarine / JOSE CARLOS DIAS DE OLIVEIRA: alertas = 2
# - Transmarine / SIDNEI DOS SANTOS: alertas = 2
# - Transmarine / UELTON DE OLIVEIRA: alertas = 2
# - Transmarine / VICTOR MACHADO: alertas = 2
# - Transmarine / anonymous: alertas = 2
# - Transpanorama - Diogo / MARCELO CORREA: alertas = 2
# - Transpanorama - Paulo / CLAUDINEI MARCONDES EVANGELISTA: alertas = 2
# - Transpanorama - Paulo / GERALDO OURIQUE DE AGUIAR FILHO: alertas = 2
# - Transportadora Pra Frente Brasil Ltda / PAULO EDSON DANTAS ZANINI: alertas = 2
# - Transportadora Pra Frente Brasil Ltda / VICTOR AFONSO DOS SANTOS HONORATO: alertas = 2
# - Transportadora sabia / EZEQUIEL LUCAS MAESTRI RIBEIRO: alertas = 2
# - Transportes Maçaneiro LTDA / PAULO REIS DE SOUZA: alertas = 2
# - Transportes Rodoviário Fedrigo LTDA / LUCAS DOS REIS: alertas = 2
# - VIA GROUP PARTICIPAÇÕES LTDA / ALAN SILVA RIBEIRO: alertas = 2
# - VIA GROUP PARTICIPAÇÕES LTDA / ANTONIO HENRIQUE ALVES NETO: alertas = 2
# - VIA GROUP PARTICIPAÇÕES LTDA / JOãO PAULO TEODORO GOMES: alertas = 2
# - VIA GROUP PARTICIPAÇÕES LTDA / LUCIANO DA SILVA CUNHA: alertas = 2
# - VIA GROUP PARTICIPAÇÕES LTDA / LUCIANO DE OLIVEIRA COSTA: alertas = 2
# - Vamos Locação / EDSON PALMA SOARES: alertas = 2
# - Vamos Locação / MARCIO FERNANDO DE AGUIAR: alertas = 2
# - Vamos Locação / MARCOS PAULO LOPES DOS SANTOS: alertas = 2
# - VirtuGNL / ADRIANO APARECIDO NASCIMENTO: alertas = 2
# - VirtuGNL / LUIS EDUARDO GONçALVES DUTRA: alertas = 2
# - Zeus Agrotech / ALBERTO BATISTA LEITE FILHO: alertas = 2
# - Zeus Agrotech / ATILA ALVES GUICHARDI: alertas = 2
# - Zeus Agrotech / ELCIO NUNES DE OLIVEIRA: alertas = 2
# - Zeus Agrotech / ELTON BARBOSA DOS SANTOS: alertas = 2
# - Zeus Agrotech / RODRIGO TEODORO DA SILVA: alertas = 2
# - Zeus Agrotech / THIAGO DE FREITAS COLOMBO: alertas = 2
# - Zeus Agrotech / WELLINGTON DORNELAS DA COSTA: alertas = 2
# - Zeus Agrotech / WENDER DOS SANTOS ALVES: alertas = 2
