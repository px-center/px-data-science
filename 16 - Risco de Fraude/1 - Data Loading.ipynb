# %%
from src.libs.lib import *
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Out:
# Hash numérica de 5 dígitos: 94799

# %%
dfs = load_data_db()
#1m 30s
# Out:
# Conexão estabelecida com sucesso!

# %%
df_original = dfs["reembolsos"]
display(df_original.head())
# Out:
#    ID do Reembolso Data da criação do reembolso  \
# 0            66220          2024-12-30 15:34:35
# 1            31526          2024-01-18 15:44:21
# 2            31603          2024-01-19 10:46:09
# 3            48047          2024-07-22 16:01:36
# 4            30580          2024-01-09 16:56:56
#
#   Data da ultima atualização do reembolso  \
# 0                     2024-12-30 16:54:11
# 1                     2024-01-18 15:51:51
# 2                     2024-01-19 10:58:16
# 3                     2024-07-22 16:08:59
# 4                     2024-01-10 12:25:05
#
#   Data da aprovação ou rejeição do reembolso Status do reembolso  \
# 0                        2024-12-30 16:54:11           Reprovado
# 1                        2024-01-18 15:51:51           Reprovado
# 2                        2024-01-19 10:58:16           Reprovado
# 3                        2024-07-22 16:08:59           Reprovado
# 4                        2024-01-10 12:24:48                Pago
#
#    ID do contrato  Valor total do reembolso Motivo do reembolso  \
# 0          130463                        92                   6
# 1           59215                        65                   0
# 2           59485                       270                   0
# 3           93563                        32                   1
# 4           58564                        70
#
#   Descrição do motivo do reembolso  Tipo do reembolso Descrição do reembolso  \
# 0               Comprovante errado                  1         Carga/Descarga
# 1                                                 101
# 2                                                 101
# 3                      Duplicidade                  1         Carga/Descarga
# 4                                                 101
#
#    ID do contrato  Número de dias agenciados do contrato  Valor do contrato  \
# 0          130463                                     12               2640
# 1           59215                                      5               1050
# 2           59485                                      5               1150
# 3           93563                                     24               6720
# 4           58564                                     22               7700
#
#    Dia da semana do contrato  ID do motorista               Nome do motorista  \
# 0                          1         191080.0           EDER DA SILVA BARBOSA
# 1                          1         108860.0         ALEX MARTINS DOS SANTOS
# 2                          1          71564.0   ERISON ERICK PEREIRA DA SILVA
# 3                          3         111923.0                 JANIEL DA SILVA
# 4                          1          30641.0  JOHN KENNEDY LOURENçO DA SILVA
#
#    Ajudante (1) ou Motorista (0)        Nome da transportadora
# 0                            0.0            GT FOODS - BARUERI
# 1                            0.0            GT FOODS - BARUERI
# 2                            0.0            GT FOODS - BARUERI
# 3                            0.0        TRANSPORTES TOZZO LTDA
# 4                            0.0  PETRÓPOLIS - FÁBRICA UBERABA

# %%
df_original.fillna(0, inplace=True)

# %%
df_original.to_csv("src/data/reembolsos.csv", index=False)
